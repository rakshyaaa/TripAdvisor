# %%
pip install -U duckduckgo-search langchain-community
# Out:
# Collecting duckduckgo-search
#   Downloading duckduckgo_search-8.1.1-py3-none-any.whl.metadata (16 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click>=8.1.8 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from duckduckgo-search) (8.2.1)
# Collecting primp>=0.15.0 (from duckduckgo-search)
#   Downloading primp-0.15.0-cp38-abi3-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: lxml>=5.3.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from duckduckgo-search) (6.0.0)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (0.3.72)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (0.3.27)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (2.0.42)
# Requirement already satisfied: requests<3,>=2 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (3.12.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (0.6.7)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (0.4.8)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=2.1.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-community) (2.3.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.4.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from requests<3,>=2->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from requests<3,>=2->langchain-community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: colorama in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from click>=8.1.8->duckduckgo-search) (0.4.6)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (3.11.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Requirement already satisfied: anyio in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in c:\rakshya\trip advisor\trip_llm_env\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Downloading duckduckgo_search-8.1.1-py3-none-any.whl (18 kB)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    --------------------------------- ------ 2.1/2.5 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 11.1 MB/s eta 0:00:00
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
# Downloading primp-0.15.0-cp38-abi3-win_amd64.whl (3.1 MB)
#    ---------------------------------------- 0.0/3.1 MB ? eta -:--:--
#    ----------------------------- ---------- 2.4/3.1 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.1/3.1 MB 11.2 MB/s eta 0:00:00
# Installing collected packages: primp, httpx-sse, duckduckgo-search, pydantic-settings, langchain-community
#
#    ---------------- ----------------------- 2/5 [duckduckgo-search]
#    ------------------------ --------------- 3/5 [pydantic-settings]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    -------------------------------- ------- 4/5 [langchain-community]
#    ---------------------------------------- 5/5 [langchain-community]
#
# Successfully installed duckduckgo-search-8.1.1 httpx-sse-0.4.1 langchain-community-0.3.27 primp-0.15.0 pydantic-settings-2.10.1
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.tools import DuckDuckGoSearchResults

tool = DuckDuckGoSearchResults()
tool.invoke("Obama")
# Out:
# c:\Rakshya\Trip Advisor\trip_llm_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:63: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# 'snippet: Barack Hussein Obama II[a] (born August 4, 1961) is an American politician who was the 44th president of the United States from 2009 to 2017. A member of the Democratic Party, he was …, title: Barack Obama - Wikipedia, link: https://en.wikipedia.org/wiki/Barack_Obama, snippet: Aug 12, 2025 · Barack Obama, the 44th President of the United States, broke barriers as the first African-American president and implemented significant healthcare reforms during his tenure., title: Barack Obama | Biography, Parents, Education, Presidency, …, link: https://www.britannica.com/biography/Barack-Obama, snippet: As President Obama has said, the change we seek will take longer than one term or one presidency. Real change—big change—takes many years and requires each generation to …, title: Barack Obama - The Office of Barack and Michelle Obama, link: https://barackobama.com/, snippet: President Obama announced plans to normalize foreign relations with Cuba in conjunction with President Castro, including reopening the U.S. Embassy in Havana in July 2015. The First …, title: President Barack Obama | Barack Obama Presidential Library, link: https://www.obamalibrary.gov/obamas/president-barack-obama'

# %%
from langchain_community.chat_models import ChatOllama
from langchain_ollama import OllamaLLM
from langchain.memory import ConversationBufferMemory
from langchain.agents import AgentType, initialize_agent, Tool

llm = OllamaLLM(
        model="llama3",
        base_url="http://localhost:11434",
        temperature=0.1,  # Low temperature for consistent, factual responses
    )
tools = [
        DuckDuckGoSearchResults()
    ]

prompt = """
You are a friendly and knowledgeable AI trip advisor assistant powered by Llama3. Your role is to help users plan their perfect trips by:

1. Researching destinations and providing up-to-date information
2. Finding popular attractions and activities
3. Suggesting accommodations based on user preferences
4. Providing local transportation options
5. Offering weather information and best travel times
6. Giving budger estimated and travel tips

Always be helpful, enthusiastic, and provide detailed, actionable advice. Use the available tools to gather information and give accurate recommendations after verifying it.

When users ask questions:
- Be conversational and friendly
- Ask clarifying questions if needed
- Use the tools to provide specific, accurate information
- Give practical tips and suggestions
- Consider their budget, interests, and travel style

Remember: You're here to make travel planning easier and more enjoyable!
"""

# %%
memory = ConversationBufferMemory(
        memory_key="chat_history",
        return_messages=True
    )
    
# Create the agent with tools and memory
agent = initialize_agent(
        tools=tools,
        llm=llm,
        agent=AgentType.CHAT_CONVERSATIONAL_REACT_DESCRIPTION,
        memory=memory,
        verbose=True,
        handle_parsing_errors=True
)

# %%
message = "I want to plan a trip to Paris. Can you help me find the best attractions, accommodations, and local tips?"

response = agent.run(message)

print(response)
# Out:
# > Entering new AgentExecutor chain...
# ```json
# {
#     "action": "duckduckgo_results_json",
#     "action_input": "best attractions in Paris"
# }
# ```
#
# This will allow the user to use DuckDuckGo's search results to find information on the best attractions in Paris. From there, we can work together to plan a trip that fits their interests and preferences!
# c:\Rakshya\Trip Advisor\trip_llm_env\Lib\site-packages\langchain_community\utilities\duckduckgo_search.py:63: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# Observation: snippet: Jul 28, 2025 · If you've been dreaming of a visit to the Eiffel Tower, Louvre Museum and Moulin Rouge, plan your trip with these …, title: 34 Best Things to Do in Paris, France - U.S. News Travel, link: https://travel.usnews.com/Paris_France/Things_To_Do/, snippet: Named after Napoleon's victory at the Battle of Rivoli and stretching from Place de la Bastille in the east to Place de la …, title: 16 Free Things to Do in Paris | U.S. News Travel, link: https://travel.usnews.com/Paris_France/Things_To_Do/Free/, snippet: May 22, 2024 · U.S. News considered factors like variety of attractions, lodging, weather and culinary scenes to create …, title: The 25 Best Places to Visit in France. - U.S. News Travel, link: https://travel.usnews.com/rankings/best-places-to-visit-in-france/, snippet: Apr 8, 2025 · On this roughly half-day cycling trip, a guide takes you on back streets to both notable and lesser-known …, title: 14 Best Paris Tours: Food, Versailles and More - U.S. News …, link: https://travel.usnews.com/features/the-best-paris-tours
# Thought:```json
# {
#     "action": "Final Answer",
#     "action_input": "The Eiffel Tower, Louvre Museum, and Moulin Rouge are must-visit attractions in Paris. Consider taking a guided cycling trip to explore the city's back streets and lesser-known spots. For accommodations, look into options near Place de la Bastille or the Seine River for easy access to popular areas. Don't forget to check out U.S. News Travel's recommendations for free things to do in Paris and the best places to visit in France."
# }
# ```
#
# > Finished chain.
# The Eiffel Tower, Louvre Museum, and Moulin Rouge are must-visit attractions in Paris. Consider taking a guided cycling trip to explore the city's back streets and lesser-known spots. For accommodations, look into options near Place de la Bastille or the Seine River for easy access to popular areas. Don't forget to check out U.S. News Travel's recommendations for free things to do in Paris and the best places to visit in France.
